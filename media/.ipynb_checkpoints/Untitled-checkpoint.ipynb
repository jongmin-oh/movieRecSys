# %%
import pandas as pd

# %%
df = pd.read_csv('result_movie.csv')

# %%
df.renmae(columns = {'title(en)':'title_en' , 'title(ko)' : 'title_ko'})
# Out:
#       movieId                                title(en)            title(ko)  \
# 0           1                         Toy Story (1995)               토이 스토리
# 1           2                           Jumanji (1995)                  쥬만지
# 2           3                  Grumpier Old Men (1995)            그럼피어 올드 맨
# 3           4                 Waiting to Exhale (1995)             사랑을 기다리며
# 4           5       Father of the Bride Part II (1995)            신부의 아버지 2
# ...       ...                                      ...                  ...
# 7293   190219                             Bunny (1998)                   버니
# 7294   193571                      Silver Spoon (2014)                  은수저
# 7295   193573  Love Live! The School Idol Movie (2015)  러브 라이브! 더 스쿨 아이돌 무비
# 7296   193583             No Game No Life: Zero (2017)      노 게임 노 라이프 -제로-
# 7297   193587      Bungo Stray Dogs: Dead Apple (2018)     문호 스트레이독스 [데드애플]
#
# ...
